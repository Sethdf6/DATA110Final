# %%
import pandas as pd

# %%
df = pd.read_csv('/home/jupyter-rohanp13/Final Project/main.csv')

df.head(20)
# Out:
#              ID                 NAME  LATITUDE  LONGITUDE  STNELEV  Year  \
# 0   ACW00011604                 SAVE   57.7667    11.8667     18.0  2011
# 1   ACW00011604                 SAVE   57.7667    11.8667     18.0  2012
# 2   ACW00011604                 SAVE   57.7667    11.8667     18.0  2013
# 3   AE000041196   SHARJAH_INTER_AIRP   25.3330    55.5170     34.0  2011
# 4   AE000041196   SHARJAH_INTER_AIRP   25.3330    55.5170     34.0  2012
# 5   AE000041196   SHARJAH_INTER_AIRP   25.3330    55.5170     34.0  2013
# 6   AE000041196   SHARJAH_INTER_AIRP   25.3330    55.5170     34.0  2014
# 7   AE000041196   SHARJAH_INTER_AIRP   25.3330    55.5170     34.0  2015
# 8   AE000041196   SHARJAH_INTER_AIRP   25.3330    55.5170     34.0  2016
# 9   AE000041196   SHARJAH_INTER_AIRP   25.3330    55.5170     34.0  2017
# 10  AE000041196   SHARJAH_INTER_AIRP   25.3330    55.5170     34.0  2018
# 11  AE000041196   SHARJAH_INTER_AIRP   25.3330    55.5170     34.0  2019
# ...

# %%
avg_temp = df[['ID', 'January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']].groupby('ID').mean()

avg_temp[['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']] = avg_temp[['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']]/100


avg_temp.head(10)
# Out:
#                January   February      March      April        May       June  \
# ID
# ACW00011604  -0.220000  -1.076667   2.740000   7.603333  12.890000  15.670000
# AE000041196  19.321111  20.451111  23.356250  28.117778  32.180000  34.616667
# AEM00041184  19.206667  20.576667  23.603333  28.000000  32.910000  35.060000
# AEM00041194  20.878000  21.740000  24.404000  28.966000  32.896000  34.936000
# AEM00041216  20.273333  21.130000  23.956667  28.583333  33.066667  34.073333
# AEM00041217  20.054286  21.182857  24.147500  29.460000  33.247500  35.052500
# AEM00041218  18.913000  20.546000  24.199000  29.362000  33.816000  36.191000
# AFM00040938   5.759000   6.945000  12.795000  18.317000  24.862000  29.745000
# AFM00040948   1.190000   3.023000   9.043000  15.043000  20.291000  25.354000
# AFM00040990   7.386250   9.232500  15.967500  22.178750  27.608750  32.177500
#
#                   July     August  September    October   November   December
# ID
# ...
